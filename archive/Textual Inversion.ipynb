# %% [markdown]
# ## A Draft of a FineTuning Tutorial
#
# All credit for model and implementation go to Divam & Francois: I simply added the `add_tokens()` method to the `SimpleTokenizer`.  To run this notebook, you need to have my fork installed so that you can use the `add_tokens()` method.
#
# **Instructions**: Install the branch of KerasCV hosted here: https://github.com/LukeWood/keras-cv/tree/lukewoodstablediffusion2
#
# Now on to the tutorial draft...

# %% [markdown]
# ## Installations
#
# If you're running this tutorial on Colab, then you'd need to install the following dependencies:

# %%
# !pip install -U -q tensorflow 
# !pip install -q tensorflow_addons
# !pip install -q ftfy

# !pip install -q git+https://github.com/LukeWood/luketils
# !pip install -q git+https://github.com/LukeWood/keras-cv.git@lukewoodstablediffusion2
# Out:
#      |████████████████████████████████| 53 kB 1.8 MB/s

# %% [markdown]
# # Textual Inversion

# %% [markdown]
# [StableDiffusion](https://stability.ai/blog/stable-diffusion-public-release): the first high quality open soruce image generator.  Since its
# release, StableDiffusion has quickly become a favorite amongst the machine learning
# community.  The high volume of traffic has led to open source contributed improvements,
# heavy prompt engineering, and even the invention of novel algorithms.
#
# Perhaps the most impressive new algorithm being used is
# [Textual-inversion](https://github.com/rinongal/textual_inversion), presented in
# [_An Image is Worth One Word: Personalizing Text-to-Image Generation using Textual Inversion_](https://textual-inversion.github.io/).
#
# Textual-inversion is the process of teaching an Image-Generator the concept of a specific
# thing through the use of FineTuning. In the diagam below, you can see an example of
# this process where the authors teach the model new concepts, calling them "S_*".
#
# ![https://i.imgur.com/KqEeBsM.jpg](https://i.imgur.com/KqEeBsM.jpg)
#
# This guide shows you how to fine-tune the StableDiffusion model shipped in KerasCV
# using the Textual-Inversion algorithm.
#
# First, lets start by important the packages we will need, and constructing StableDiffusion so we can use some of the sub-components for fine-tuning.

# %%
import keras_cv
from keras_cv import layers as cv_layers
import tensorflow as tf
from tensorflow import keras
from luketils import visualization
import numpy as np

stable_diffusion = keras_cv.models.StableDiffusion()
# Out:
# Downloading data from https://github.com/openai/CLIP/blob/main/clip/bpe_simple_vocab_16e6.txt.gz?raw=true
# 1356917/1356917 [==============================] - 0s 0us/step
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_encoder.h5
# 492466864/492466864 [==============================] - 4s 0us/step
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_diffusion_model.h5
# 3439090152/3439090152 [==============================] - 34s 0us/step
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_decoder.h5
# 198180272/198180272 [==============================] - 1s 0us/step

# %% [markdown]
# ## Generating a Fine-Tuning dataset
#
# First, we need to generate a Fine-Tuning dataset.
# This dataset must consist of text to image pairs, just as you would expect with a
# text-to-image model.
#
# First, lets fetch our images.  By default, the StableDiffusion model in KerasCV uses
# an image size of 512x512.  As such, we resize our images to 512x512.

# %%
urls = [
    "https://i.imgur.com/VIedH1X.jpg",
    "https://i.imgur.com/1WCfWUt.jpg",
    "https://i.imgur.com/eBw13hE.png",
]
files = [tf.keras.utils.get_file(origin=url) for url in urls]

# Resize images
resize = keras.layers.Resizing(height=512, width=512, crop_to_aspect_ratio=True)
images = [keras.utils.load_img(img) for img in files]
images = [keras.utils.img_to_array(img) for img in images]
images = np.array([resize(img) for img in images])
# Out:
# Downloading data from https://i.imgur.com/VIedH1X.jpg
# 102919/102919 [==============================] - 0s 2us/step
# Downloading data from https://i.imgur.com/1WCfWUt.jpg
# 102919/102919 [==============================] - 0s 2us/step
# Downloading data from https://i.imgur.com/eBw13hE.png
# 158821/158821 [==============================] - 0s 2us/step

# %%
visualization.plot_gallery(images, value_range=(0, 255), rows=1, columns=3, show=True)

# %% [markdown]
# StableDiffusion expects images to be in the value range (-1, 1), so lets normalize to that range:

# %%
images = images / 127.5 - 1
visualization.plot_gallery(images, value_range=(-1, 1), rows=1, columns=3, show=True)

# %% [markdown]
# Looks good!
#
# Next, we'll need to produce accompanying text prompts.
# Here is a small set of prompts we can use to generate a simple dataset.
# If you're finetuning on a style you should use the style prompts.

# %%
object_prompts = [
    "a photo of a {}",
    "a rendering of a {}",
    "a cropped photo of the {}",
    "the photo of a {}",
    "a photo of a clean {}",
    "a photo of a dirty {}",
    "a dark photo of the {}",
    "a photo of my {}",
    "a photo of the cool {}",
    "a close-up photo of a {}",
    "a bright photo of the {}",
    "a cropped photo of a {}",
    "a photo of the {}",
    "a good photo of the {}",
    "a photo of one {}",
    "a close-up photo of the {}",
    "a rendition of the {}",
    "a photo of the clean {}",
    "a rendition of a {}",
    "a photo of a nice {}",
    "a good photo of a {}",
    "a photo of the nice {}",
    "a photo of the small {}",
    "a photo of the weird {}",
    "a photo of the large {}",
    "a photo of a cool {}",
    "a photo of a small {}",
]

style_prompts = [
    "a painting in the style of {}",
    "a rendering in the style of {}",
    "a cropped painting in the style of {}",
    "the painting in the style of {}",
    "a clean painting in the style of {}",
    "a dirty painting in the style of {}",
    "a dark painting in the style of {}",
    "a picture in the style of {}",
    "a cool painting in the style of {}",
    "a close-up painting in the style of {}",
    "a bright painting in the style of {}",
    "a cropped painting in the style of {}",
    "a good painting in the style of {}",
    "a close-up painting in the style of {}",
    "a rendition in the style of {}",
    "a nice painting in the style of {}",
    "a small painting in the style of {}",
    "a weird painting in the style of {}",
    "a large painting in the style of {}",
]

# %% [markdown]
# You can also get creative with these prompts. Authors of [CLIP](https://arxiv.org/abs/2103.00020), experimented with 80 such prompts that you can find [here](https://github.com/openai/CLIP/blob/main/notebooks/Prompt_Engineering_for_ImageNet.ipynb).
#
# Next, lets pick a token for our new concept.
# In this guide, we use the token `"<S*>"`, but the concept
# can be named anything.

# %%
placeholder_token = "<my-funny-cat-token>"

# %%
object_prompts = [prompt.format(placeholder_token) for prompt in object_prompts]
style_prompts = [prompt.format(placeholder_token) for prompt in style_prompts]

print("object prompt:", object_prompts[0])
print("style prompt:", style_prompts[0])
# Out:
# object prompt: a photo of a <my-funny-cat-token>
# style prompt: a painting in the style of <my-funny-cat-token>

# %% [markdown]
# Now all that is left to do is a package the datsaet into a `tf.data` pipeline.

# %%
auto = tf.data.AUTOTUNE
augmentation_model = keras.Sequential(
    [
        cv_layers.RandomCropAndResize(
            target_size=(512, 512),
            crop_area_factor=(0.8, 1.0),
            aspect_ratio_factor=(1.0, 1.0),
        ),
        cv_layers.RandomFlip(mode="horizontal"),
    ],
    name="augmentation_model",
)


image_dataset = tf.data.Dataset.from_tensor_slices(images)
image_dataset = image_dataset.shuffle(100)
image_dataset = image_dataset.map(augmentation_model, auto)
image_dataset = image_dataset.repeat()

item = next(iter(image_dataset.batch(8).take(1)))
visualization.plot_gallery(item, value_range=(-1, 1), rows=2, columns=4, show=True)

# %% [markdown]
# Great!  Our images are correctly augmented in a performant `tf.data.Dataset` pipeline.
#
# For text, we first pass our embeddings through the `stable_diffusion.tokenizer.encode()` method.

# %%
# Replace with style_prompts if you'd like to finetune on a style
embeddings = [stable_diffusion.tokenizer.encode(prompt) for prompt in object_prompts]
print(f"{object_prompts[0]} => {embeddings[0]}")
# Out:
# a photo of a <my-funny-cat-token> => [49406, 320, 1125, 539, 320, 283, 607, 268, 3789, 268, 2368, 268, 17134, 285, 49407]

# %% [markdown]
# A naive pass through is not sufficient though!
# For high quality finetuning, we must add a special token to the tokenizer:

# %%
stable_diffusion.tokenizer.add_tokens(placeholder_token)

# Replace with style_prompts if you'd like to finetune on a style
embeddings = [stable_diffusion.tokenizer.encode(prompt) for prompt in object_prompts]
print(f"{object_prompts[0]} => {embeddings[0]}")
# Out:
# a photo of a <my-funny-cat-token> => [49406, 320, 1125, 539, 320, 48973, 49407]

# %% [markdown]
# Next, we need to pad the embeddings so that they're of a uniform shape. We need them to be in a uniform shape so that we can batch them together for efficient computation.

# %%
MAX_PROMPT_LENGTH = 77


def pad_embedding(embedding):
    return embedding + ([49407] * (MAX_PROMPT_LENGTH - len(embedding)))


embeddings = [np.array(pad_embedding(embedding)) for embedding in embeddings]
text_dataset = tf.data.Dataset.from_tensor_slices(embeddings)

# %% [markdown]
# Great!    As you can see, `320, 283, 607, 268, 3789, 268, 2368, 268, 17134, 285` became
# a single token: `48973`.  This is the special token we have constructed for `<my-funny-cat-token>`.
#
# Now we can collate the image and the text datasets together to obtain our final dataset for fine-tuning.

# %%
train_ds = tf.data.Dataset.zip((image_dataset, text_dataset))
train_ds = train_ds.batch(1)

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 77), dtype=tf.int64, name=None))

# %% [markdown]
# So, our final dataset contains images and the embeddings of the text prompts.

# %% [markdown]
# ## Training
#
# Now we can move on to the exciting part: training!
#
# In TextualInversion the only piece of the model that is trained is the embedding vector.  Lets freeze the rest of the model.

# %%
stable_diffusion.diffusion_model.trainable = False
stable_diffusion.decoder.trainable = False
stable_diffusion.text_encoder.trainable = True

# %% [markdown]
# Let's plot the text encoder model to know which layer within the text encoder model we need to train.

# %%
keras.utils.plot_model(stable_diffusion.text_encoder)

# %% [markdown]
# As per the plot above, we need to unfreeze the _third_ layer in the text encoder model.

# %%
stable_diffusion.text_encoder.layers[2].trainable = True

# %%
def traverse_layers(layer):
    if hasattr(layer, "layers"):
        for layer in layer.layers:
            yield layer
    if hasattr(layer, "token_embedding"):
        yield layer.token_embedding
    if hasattr(layer, "position_embedding"):
        yield layer.position_embedding


for layer in traverse_layers(stable_diffusion.text_encoder):
    if isinstance(layer, keras.layers.Embedding) or "clip_embedding" in layer.name:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
all_models = [
    stable_diffusion.text_encoder,
    stable_diffusion.diffusion_model,
    stable_diffusion.decoder,
]
print([[w.shape for w in model.trainable_weights] for model in all_models])
# Out:
# [[TensorShape([49408, 768]), TensorShape([77, 768])], [], []]

# %% [markdown]
# Great!  Our weights are correctly frozen; except for the ClipEmbedding layer.
#
# Next, we must produce a `DDPMNoiseScheduler`.  Our `DDPMNoiseScheduler` is based on the [HuggingFace implementation](https://github.com/huggingface/diffusers/blob/v0.3.0/src/diffusers/schedulers/scheduling_ddpm.py#L56).

# %%
# TODO(lukewood): add noise to the latents

# %% [markdown]
# Finally, we implement a `StableDiffusionFineTuner`.  The `StableDiffusionFineTuner` is a subclass of `keras.Model` with a custom `train_step()` override.

# %%
class StableDiffusionFineTuner(keras.Model):
    def __init__(self, stable_diffusion, **kwargs):
        super().__init__(**kwargs)
        self.stable_diffusion = stable_diffusion

    def train_step(self, data):
        images, embeddings = data
        # to train the model, we actually need the VAE Encoder - which is not currently
        # available in the package.
        # Here is the best implementation of the VAE Encoder:
        # https://github.com/huggingface/diffusers/blob/d934d3d79519653ad4db5b63a7665c1536b4187c/src/diffusers/models/vae.py#L485

        # Encoder:
        # https://github.com/huggingface/diffusers/blob/d934d3d79519653ad4db5b63a7665c1536b4187c/src/diffusers/models/vae.py#L54
        return {"loss": 0.0}

# %% [markdown]
# To monitor training, we can produce a `keras.callbacks.Callback` to produce an image every epoch using our custom token.

# %%
class GenerateImageEachEpoch(keras.callbacks.Callback):
    def __init__(self, stable_diffusion, prompt, **kwargs):
        super().__init__(**kwargs)
        self.stable_diffusion = stable_diffusion
        self.prompt = prompt

    def on_epoch_end(self, epoch, logs):
        images = self.stable_diffusion.text_to_image(self.prompt, batch_size=3)
        visualization.plot_gallery(
            images, value_range=(0, 255), rows=1, columns=3, show=True
        )

# %% [markdown]
# Next we can just `compile()` and `fit()` our model like any other Keras model!

# %%
trainer = StableDiffusionFineTuner(stable_diffusion, name="trainer")

# %%
optimizer = keras.optimizers.SGD(learning_rate=5e-4)
trainer.compile(optimizer=optimizer, loss="mse")
trainer.fit(
    train_ds,
    epochs=10,
    steps_per_epoch=3,
    callbacks=[
        GenerateImageEachEpoch(
            stable_diffusion, prompt="<my-funny-cat-token> holding a sword"
        )
    ],
)
# Out:
# Epoch 1/10
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0000e+00
#   0   1: 100%|████████████████████████████████████████████████████████████████████████████████| 25/25 [01:13<00:00,  2.96s/it]
# 3/3 [==============================] - 94s 47s/step - loss: 0.0000e+00
# Epoch 2/10
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0000e+00
#   0   1: 100%|████████████████████████████████████████████████████████████████████████████████| 25/25 [01:01<00:00,  2.44s/it]
# 3/3 [==============================] - 63s 32s/step - loss: 0.0000e+00
# Epoch 3/10
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0000e+00
#   0   1: 100%|████████████████████████████████████████████████████████████████████████████████| 25/25 [01:01<00:00,  2.44s/it]
# 3/3 [==============================] - 64s 32s/step - loss: 0.0000e+00
# Epoch 4/10
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0000e+00
#  23 921:   4%|███▏                                                                             | 1/25 [00:03<01:27,  3.64s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 optimizer = keras.optimizers.SGD(learning_rate=5e-4)
#       2 trainer.compile(optimizer=optimizer, loss='mse')
# ----> 3 trainer.fit(
#       4     train_ds,
#       5     epochs=10,
#       6     steps_per_epoch=3,
#       7     callbacks=[
#       8         GenerateImageEachEpoch(stable_diffusion, prompt='<my-funny-cat-token> holding a sword')
#       9     ]
#      10 )
#
# File ~/.local/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.9/site-packages/keras/engine/training.py:1460, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1457   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1458   epoch_logs.update(val_logs)
# -> 1460 callbacks.on_epoch_end(epoch, epoch_logs)
#    1461 training_logs = epoch_logs
#    1462 if self.stop_training:
#
# File ~/.local/lib/python3.9/site-packages/keras/callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     414 logs = self._process_logs(logs)
#     415 for callback in self.callbacks:
# --> 416   callback.on_epoch_end(epoch, logs)
#
# Input In [19], in GenerateImageEachEpoch.on_epoch_end(self, epoch, logs)
#       7 def on_epoch_end(self, epoch, logs):
# ----> 8     images = self.stable_diffusion.text_to_image(self.prompt, batch_size=3)
#       9     visualization.plot_gallery(images, value_range=(0, 255), rows=1, columns=3, show=True)
#
# File ~/workspace/keras-cv/keras_cv/models/generative/stable_diffusion/stable_diffusion.py:93, in StableDiffusion.text_to_image(self, prompt, batch_size, num_steps, unconditional_guidance_scale, temperature, seed)
#      91 for index, timestep in progbar:
#      92     progbar.set_description(f"{index:3d} {timestep:3d}")
# ---> 93     e_t = self.diffusion_step(
#      94         latent,
#      95         timestep,
#      96         context,
#      97         unconditional_context,
#      98         unconditional_guidance_scale,
#      99         batch_size,
#     100     )
#     101     a_t, a_prev = alphas[index], alphas_prev[index]
#     102     latent, _ = self.get_x_prev_and_pred_x0(
#     103         latent, e_t, index, a_t, a_prev, temperature, seed
#     104     )
#
# File ~/workspace/keras-cv/keras_cv/models/generative/stable_diffusion/stable_diffusion.py:132, in StableDiffusion.diffusion_step(self, latent, t, context, unconditional_context, unconditional_guidance_scale, batch_size)
#     130 t_emb = self.timestep_embedding(timesteps)
#     131 t_emb = np.repeat(t_emb, batch_size, axis=0)
# --> 132 unconditional_latent = self.diffusion_model.predict_on_batch(
#     133     [latent, t_emb, unconditional_context]
#     134 )
#     135 latent = self.diffusion_model.predict_on_batch([latent, t_emb, context])
#     136 return unconditional_latent + unconditional_guidance_scale * (
#     137     latent - unconditional_latent
#     138 )
#
# File ~/.local/lib/python3.9/site-packages/keras/engine/training.py:2231, in Model.predict_on_batch(self, x)
#    2229   self.predict_function = self.make_predict_function()
#    2230   outputs = self.predict_function(iterator)
# -> 2231 return tf_utils.sync_to_numpy_or_python_type(outputs)
#
# File ~/.local/lib/python3.9/site-packages/keras/utils/tf_utils.py:607, in sync_to_numpy_or_python_type(tensors)
#     604     return t
#     605   return t.item() if np.ndim(t) == 0 else t
# --> 607 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~/.local/lib/python3.9/site-packages/tensorflow/python/util/nest.py:916, in map_structure(func, *structure, **kwargs)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~/.local/lib/python3.9/site-packages/tensorflow/python/util/nest.py:916, in <listcomp>(.0)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~/.local/lib/python3.9/site-packages/keras/utils/tf_utils.py:601, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     598 def _to_single_numpy_or_python_type(t):
#     599   # Don't turn ragged or sparse tensors to NumPy.
#     600   if isinstance(t, tf.Tensor):
# --> 601     t = t.numpy()
#     602   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     603   if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~/.local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1159, in _EagerTensorBase.numpy(self)
#    1136 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1137
#    1138 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1156     NumPy dtype.
#    1157 """
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~/.local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1125, in _EagerTensorBase._numpy(self)
#    1123 def _numpy(self):
#    1124   try:
# -> 1125     return self._numpy_internal()
#    1126   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
